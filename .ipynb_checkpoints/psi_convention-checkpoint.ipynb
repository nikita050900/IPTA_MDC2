# %%
libstempo.libstempo import add_cgw

# %%
#!/usr/bin/env python3
"""
LIBSTEMPO SIDE
Compute and save antenna pattern info for one pulsar in IPTA_MDC2 dataset_2.
Also generate CW residuals with and without the pulsar term.
Run this inside the Singularity container where libstempo works.
"""

import numpy as np
import libstempo as lt
import os

# ---- try to import add_cgw safely ----
try:
    from libstempo.cw import add_cgw
except ImportError:
    try:
        add_cgw = lt.add_cgw
    except AttributeError:
        raise ImportError(
            "Could not find add_cgw. Your libstempo build may require direct access.\n"
            "Try importing via: from libstempo.libstempo import add_cgw"
        )

# final fallback
if not callable(add_cgw):
    from libstempo.libstempo import add_cgw

# ---------- CONFIG ----------
parfile = "/scratch/na00078/projects/IPTA_MDC2/mdc2/group2/dataset_2/par/J1603-7202.par"
timfile = "/scratch/na00078/projects/IPTA_MDC2/mdc2/group2/dataset_2/tim/J1603-7202.tim"

# GW injection parameters from dataset_2
gwtheta = 0.6387905062299246
gwphi   = 3.3335788713091694
psi_inj = 1.1187560505283651
phase0_inj = 0.24434609527920614
# Optional physical values (not strictly needed for Fp/Fx)
mc    = 4.3e9     # solar masses
dist  = 75.4      # Mpc
fgw   = 3.7e-9    # Hz
inc   = 0.8412486994612669
tref  = 0.0       # fiducial reference time
# -----------------------------

def triad_libstempo(theta, phi):
    m  = np.array([np.sin(phi), -np.cos(phi), 0.0])
    n  = np.array([-np.cos(theta)*np.cos(phi),
                   -np.cos(theta)*np.sin(phi),
                    np.sin(theta)])
    Om = np.array([-np.sin(theta)*np.cos(phi),
                   -np.sin(theta)*np.sin(phi),
                   -np.cos(theta)])
    return m, n, Om

def phat_from_psr(psr):
    dec = psr["DECJ"].val
    ra  = psr["RAJ"].val
    ptheta = np.pi/2 - dec
    pphi   = ra
    phat = np.array([np.sin(ptheta)*np.cos(pphi),
                     np.sin(ptheta)*np.sin(pphi),
                     np.cos(ptheta)])
    return phat

def antenna_patterns(m, n, Om, phat):
    cosMu = -np.dot(Om, phat)
    denom = 1.0 - cosMu
    Fp = 0.5 * ((m@phat)**2 - (n@phat)**2) / denom
    Fx =      ((m@phat) * (n@phat)) / denom
    return Fp, Fx


# ---- Load pulsar ----
psr = lt.tempopulsar(parfile, timfile)
phat = phat_from_psr(psr)
m_ls, n_ls, Om_ls = triad_libstempo(gwtheta, gwphi)

# ---- Compute patterns ----
Fp_ls, Fx_ls = antenna_patterns(m_ls, n_ls, Om_ls, phat)

# ---- Compute residuals for testing (Earth term vs full term) ----
print("\nGenerating CW residuals for diagnostic check...")
for psrTerm_flag in [True, False]:
    psr_temp = lt.tempopulsar(parfile, timfile)  # reload fresh pulsar
    add_cgw(psr_temp, gwtheta, gwphi, mc, dist, fgw,
        phase0_inj, psi_inj, inc,
        psrTerm=psrTerm_flag, tref=tref)

    tag = "psr" if psrTerm_flag else "earth"
    res = psr_temp.residuals()
    np.save(f"residuals_{tag}.npy", res)
    print(f"Saved residuals_{tag}.npy (psrTerm={psrTerm_flag})")

# ---- Save antenna patterns ----
np.save("F_libstempo_psr.npy", np.array([Fp_ls, Fx_ls]))
np.save("F_libstempo_earth.npy", np.array([Fp_ls, Fx_ls]))  # same Fp/Fx, but easier bookkeeping
np.save("phat_libstempo.npy", phat)

print("\nSaved:")
print("  F_libstempo_psr.npy  (with pulsar term)")
print("  F_libstempo_earth.npy (Earth term only, same Fp/Fx)")
print("  phat_libstempo.npy (unit vector)")
print(f"Fp={Fp_ls:.6e}, Fx={Fx_ls:.6e}")
print(f"Injection psi={psi_inj:.6f}, phase0={phase0_inj:.6f}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [5], line 15
#      14 try:
# ---> 15     from libstempo.cw import add_cgw
#      16 except ImportError:
#
# ModuleNotFoundError: No module named 'libstempo.cw'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In [5], line 18
#      17 try:
# ---> 18     add_cgw = lt.add_cgw
#      19 except AttributeError:
#
# AttributeError: module 'libstempo' has no attribute 'add_cgw'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In [5], line 20
#      18         add_cgw = lt.add_cgw
#      19     except AttributeError:
# ---> 20         raise ImportError(
#      21             "Could not find add_cgw. Your libstempo build may require direct access.\n"
#      22             "Try importing via: from libstempo.libstempo import add_cgw"
#      23         )
#      25 # final fallback
#      26 if not callable(add_cgw):
#
# ImportError: Could not find add_cgw. Your libstempo build may require direct access.
# Try importing via: from libstempo.libstempo import add_cgw

# %%
#!/usr/bin/env python3
"""
LIBSTEMPO SIDE
Compute and save antenna pattern info for one pulsar in IPTA_MDC2 dataset_2.
Run this inside the Singularity container where libstempo works.
"""

import numpy as np
import libstempo as lt
import os

# ---------- CONFIG ----------
# pick any representative pulsar in dataset_2
parfile = "/scratch/na00078/projects/IPTA_MDC2/mdc2/group2/dataset_2/par/J1603-7202.par"
timfile = "/scratch/na00078/projects/IPTA_MDC2/mdc2/group2/dataset_2/tim/J1603-7202.tim"

# GW injection parameters from dataset_2
gwtheta = 0.6387905062299246
gwphi   = 3.3335788713091694
psi_inj = 1.1187560505283651
phase0_inj = 0.24434609527920614
# -----------------------------

def triad_libstempo(theta, phi):
    m  = np.array([np.sin(phi), -np.cos(phi), 0.0])
    n  = np.array([-np.cos(theta)*np.cos(phi),
                   -np.cos(theta)*np.sin(phi),
                    np.sin(theta)])
    Om = np.array([-np.sin(theta)*np.cos(phi),
                   -np.sin(theta)*np.sin(phi),
                   -np.cos(theta)])
    return m, n, Om

def phat_from_psr(psr):
    dec = psr["DECJ"].val
    ra  = psr["RAJ"].val
    ptheta = np.pi/2 - dec
    pphi   = ra
    phat = np.array([np.sin(ptheta)*np.cos(pphi),
                     np.sin(ptheta)*np.sin(pphi),
                     np.cos(ptheta)])
    return phat

def antenna_patterns(m, n, Om, phat):
    cosMu = -np.dot(Om, phat)
    denom = 1.0 - cosMu
    Fp = 0.5 * ((m@phat)**2 - (n@phat)**2) / denom
    Fx =      ((m@phat) * (n@phat)) / denom
    return Fp, Fx

# ---- compute patterns ----
psr = lt.tempopulsar(parfile, timfile)
phat = phat_from_psr(psr)
m_ls, n_ls, Om_ls = triad_libstempo(gwtheta, gwphi)
Fp_ls, Fx_ls = antenna_patterns(m_ls, n_ls, Om_ls, phat)

# ---- save for QuickCW side ----
np.save("F_libstempo.npy", np.array([Fp_ls, Fx_ls]))
np.save("phat_libstempo.npy", phat)

print("Saved F_libstempo.npy and phat_libstempo.npy")
print(f"Fp={Fp_ls:.6e}, Fx={Fx_ls:.6e}")
print(f"Injection psi={psi_inj:.6f}, phase0={phase0_inj:.6f}")
# Out:
# Saved F_libstempo.npy and phat_libstempo.npy
# Fp=-1.435472e-01, Fx=1.041502e-01
# Injection psi=1.118756, phase0=0.244346
