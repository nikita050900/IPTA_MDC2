# %%
# Prereqs: enterprise, and either TEMPO2 (installed & in PATH) or PINT
# If using TEMPO2, make sure T2 ephemerides & clock files are available.
# If using PINT, it will auto-fetch clock/ephem files if configured.

from pathlib import Path
import pickle
from enterprise.pulsar import Pulsar

# Choose timing engine: "tempo2" or "pint"
TIMING_PKG = "tempo2"   # change to "pint" if you prefer PINT
# Out:
# WARNING: AstropyDeprecationWarning: The private astropy._erfa module has been made into its own package, pyerfa, which is a dependency of astropy and can be imported directly using "import erfa" [astropy._erfa]

# %%
from pathlib import Path
import pickle
from enterprise.pulsar import Pulsar

# ---- CONFIG ----
TIMING_PKG = "tempo2"   # or "pint"
BASE = Path("/scratch/na00078/projects/IPTA_MDC2/mdc2/group2/dataset_2")
PAR_DIR = BASE / "par"
TIM_DIR = BASE / "tim"
OUT_FILE = BASE / "dataset2_all_pulsars.pkl"

# ---- BUILD ALL ----
pars = sorted(PAR_DIR.glob("*.par"))
pulsars = []
skipped = []

for par in pars:
    tim = TIM_DIR / (par.stem + ".tim")
    if not tim.exists():
        skipped.append((par.name, "missing tim"))
        continue
    try:
        psr = Pulsar(str(par), str(tim), timing_package=TIMING_PKG)
        pulsars.append(psr)
        print(f"✔ {par.stem}: {len(psr.toas)} TOAs")
    except Exception as e:
        skipped.append((par.name, str(e)))

# ---- SAVE SINGLE PKL ----
with open(OUT_FILE, "wb") as f:
    pickle.dump(pulsars, f, protocol=pickle.HIGHEST_PROTOCOL)

print(f"\nSaved {len(pulsars)} pulsars -> {OUT_FILE}")
if skipped:
    print("Skipped:")
    for name, reason in skipped:
        print("  ✖", name, "->", reason)
# Out:
# WARNING: Could not find pulsar distance for PSR J0034-0534. Setting value to 1 with 20% uncertainty.
# ✔ J0030+0451: 183 TOAs
# ✔ J0034-0534: 183 TOAs
# WARNING: Could not find pulsar distance for PSR J0218+4232. Setting value to 1 with 20% uncertainty.
# ✔ J0218+4232: 183 TOAs
# ✔ J0437-4715: 183 TOAs
# WARNING: Could not find pulsar distance for PSR J0621+1002. Setting value to 1 with 20% uncertainty.
# ✔ J0613-0200: 183 TOAs
# ✔ J0621+1002: 183 TOAs
# WARNING: Could not find pulsar distance for PSR J0751+1807. Setting value to 1 with 20% uncertainty.
# ✔ J0711-6830: 183 TOAs
# WARNING: Could not find pulsar distance for PSR J0900-3144. Setting value to 1 with 20% uncertainty.
# ✔ J0751+1807: 183 TOAs
# ✔ J0900-3144: 183 TOAs
# ✔ J1012+5307: 183 TOAs
# ✔ J1022+1001: 183 TOAs
# ✔ J1024-0719: 183 TOAs
# ✔ J1045-4509: 183 TOAs
# ✔ J1455-3330: 183 TOAs
# ✔ J1600-3053: 183 TOAs
# WARNING: Could not find pulsar distance for PSR J1614-2230. Setting value to 1 with 20% uncertainty.
# ✔ J1603-7202: 183 TOAs
# ✔ J1614-2230: 183 TOAs
# ✔ J1640+2224: 183 TOAs
# ✔ J1643-1224: 183 TOAs
# ✔ J1713+0747: 183 TOAs
# ✔ J1730-2304: 183 TOAs
# ✔ J1744-1134: 183 TOAs
# ✔ J1857+0943: 183 TOAs
# ✔ J1909-3744: 183 TOAs
# ✔ J1918-0642: 183 TOAs
# WARNING: Could not find pulsar distance for PSR J1944+0907. Setting value to 1 with 20% uncertainty.
# ✔ J1939+2134: 183 TOAs
# WARNING: Could not find pulsar distance for PSR J2010-1323. Setting value to 1 with 20% uncertainty.
# ✔ J1944+0907: 183 TOAs
# ✔ J2010-1323: 183 TOAs
# ✔ J2124-3358: 183 TOAs
# ✔ J2129-5721: 183 TOAs
# WARNING: Could not find pulsar distance for PSR J2229+2643. Setting value to 1 with 20% uncertainty.
# ✔ J2145-0750: 183 TOAs
# ✔ J2229+2643: 183 TOAs
# ✔ J2317+1439: 183 TOAs
#
# Saved 33 pulsars -> /scratch/na00078/projects/IPTA_MDC2/mdc2/group2/dataset_2/dataset2_all_pulsars.pkl

# %%
import pickle

with open("/scratch/na00078/projects/IPTA_MDC2/mdc2/group2/dataset_2/dataset2_all_pulsars.pkl", "rb") as f:
    pulsars = pickle.load(f)

print(f"Loaded {len(pulsars)} pulsars")
print([psr.name for psr in pulsars[:5]])  # show first 5 names
# Out:
# Loaded 33 pulsars
# ['J0030+0451', 'J0034-0534', 'J0218+4232', 'J0437-4715', 'J0613-0200']

# %%
import pickle
import numpy as np

# Load your combined pickle
pkl_file = "/scratch/na00078/projects/IPTA_MDC2/mdc2/group2/dataset_2/dataset2_all_pulsars.pkl"

with open(pkl_file, "rb") as f:
    pulsars = pickle.load(f)

print(f"Total pulsars in file: {len(pulsars)}\n")

# Inspect the first 3 pulsars
for i, psr in enumerate(pulsars[:3], start=1):
    print(f"--- Pulsar {i}: {psr.name} ---")
    print(f"Number of TOAs: {len(psr.toas)}")
    print(f"Observatories: {set(psr.obs_flags)}")
    print(f"TOA range (MJD): {psr.toas.min():.2f} – {psr.toas.max():.2f}")
    print(f"Frequency range (MHz): {psr.freqs.min():.1f} – {psr.freqs.max():.1f}")
    print(f"First 5 frequencies: {psr.freqs[:5]}")
    print(f"First 5 residuals (s): {psr.residuals[:5]}")
    print(f"Noise parameters present: {list(psr.noise_params.keys())}\n")
# Out:
# Total pulsars in file: 33
#
# --- Pulsar 1: J0030+0451 ---
# Number of TOAs: 183
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [5], line 16
#      14 print(f"--- Pulsar {i}: {psr.name} ---")
#      15 print(f"Number of TOAs: {len(psr.toas)}")
# ---> 16 print(f"Observatories: {set(psr.obs_flags)}")
#      17 print(f"TOA range (MJD): {psr.toas.min():.2f} – {psr.toas.max():.2f}")
#      18 print(f"Frequency range (MHz): {psr.freqs.min():.1f} – {psr.freqs.max():.1f}")
#
# AttributeError: 'Tempo2Pulsar' object has no attribute 'obs_flags'

# %%
import pickle

with open("/scratch/na00078/projects/15yr_data/15yrCW/v1p1_de440_pint_bipm2019_unshifted_pdist.pkl", "rb") as f:
    pulsars = pickle.load(f)

print(f"Loaded {len(pulsars)} pulsars")
print([psr.name for psr in pulsars[:5]])  # show first 5 names
# Out:
# Loaded 67 pulsars
# ['B1855+09', 'B1937+21', 'B1953+29', 'J0023+0923', 'J0030+0451']

# %%
import pickle
import numpy as np

# Load your combined pickle
pkl_file = "/scratch/na00078/projects/15yr_data/15yrCW/v1p1_de440_pint_bipm2019_unshifted_pdist.pkl"

with open(pkl_file, "rb") as f:
    pulsars = pickle.load(f)

print(f"Total pulsars in file: {len(pulsars)}\n")

# Inspect the first 3 pulsars
for i, psr in enumerate(pulsars[:3], start=1):
    print(f"--- Pulsar {i}: {psr.name} ---")
    print(f"Number of TOAs: {len(psr.toas)}")
    print(f"Observatories: {set(psr.obs_flags)}")
    print(f"TOA range (MJD): {psr.toas.min():.2f} – {psr.toas.max():.2f}")
    print(f"Frequency range (MHz): {psr.freqs.min():.1f} – {psr.freqs.max():.1f}")
    print(f"First 5 frequencies: {psr.freqs[:5]}")
    print(f"First 5 residuals (s): {psr.residuals[:5]}")
    print(f"Noise parameters present: {list(psr.noise_params.keys())}\n")
# Out:
# Total pulsars in file: 67
#
# --- Pulsar 1: B1855+09 ---
# Number of TOAs: 7758
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [6], line 16
#      14 print(f"--- Pulsar {i}: {psr.name} ---")
#      15 print(f"Number of TOAs: {len(psr.toas)}")
# ---> 16 print(f"Observatories: {set(psr.obs_flags)}")
#      17 print(f"TOA range (MJD): {psr.toas.min():.2f} – {psr.toas.max():.2f}")
#      18 print(f"Frequency range (MHz): {psr.freqs.min():.1f} – {psr.freqs.max():.1f}")
#
# AttributeError: 'PintPulsar' object has no attribute 'obs_flags'

# %%
from pathlib import Path
import re, pickle

BASE = Path("/scratch/na00078/projects/IPTA_MDC2/mdc2/group2/dataset_2")
PAR_IN  = BASE / "par_pint_clean"        # from your previous cleaning step
PAR_OUT = BASE / "par_pint_compat"       # new, more compatible copies
TIM_DIR = BASE / "tim"
OUT_PKL = BASE / "dataset2_all_pulsars_pint.pkl"

PAR_OUT.mkdir(exist_ok=True, parents=True)

def decide_binary_model(lines):
    """Infer best replacement model from params present."""
    # Token presence checks (cheap & robust)
    has_eps   = any(re.match(r"\s*(EPS1|EPS2)\b", l) for l in lines)
    has_h3h4  = any(re.match(r"\s*(H3|H4|STIG)\b", l) for l in lines)
    if has_eps and has_h3h4:
        return "ELL1H"
    if has_eps:
        return "ELL1"
    # fall back
    return "DD"

def transform_par_text(text):
    lines = text.splitlines()

    # snapshot presence for model decision
    model_guess = decide_binary_model(lines)

    out = []
    forced_unites = False
    saw_units = False
    saw_timeeph = False
    binary_line_idx = None

    for idx, line in enumerate(lines):
        s = line.strip()

        # keep comments/blank
        if not s or s.startswith("#") or s.startswith("C "):
            out.append(line); continue

        tok = s.split()[0]

        # Force UNITS TDB
        if tok == "UNITS":
            saw_units = True
            if "TDB" not in s:
                out.append("UNITS TDB")
            else:
                out.append(line)
            continue

        # Force TIMEEPH FB90 (drop other settings)
        if tok == "TIMEEPH":
            saw_timeeph = True
            out.append("TIMEEPH FB90")
            continue

        # Drop Tempo2-only / unsupported switches
        if tok == "DILATEFREQ":
            # PINT warns: not supported
            continue

        # Map Tempo2 meta-binary or unsupported models
        if tok == "BINARY":
            model = s.split()[1] if len(s.split()) > 1 else ""
            if model == "T2":
                # Choose specific model based on parameters
                repl = decide_binary_model(lines)
                out.append(f"BINARY {repl}")
                binary_line_idx = len(out)-1
                continue
            if model == "DDH":
                # Prefer ELL1H if EPS* present; else fall back to DD
                repl = "ELL1H" if decide_binary_model(lines) in ("ELL1H","ELL1") else "DD"
                out.append(f"BINARY {repl}")
                binary_line_idx = len(out)-1
                continue

        out.append(line)

    # If no UNITS line, inject TDB at top (some T2 pars omit it)
    if not saw_units:
        out.insert(0, "UNITS TDB")

    # If no TIMEEPH line, inject FB90 (what PINT supports)
    if not saw_timeeph:
        out.insert(1, "TIMEEPH FB90")

    return "\n".join(out) + "\n"

# --- Write transformed PARs ---
transformed = []
for par in sorted(PAR_IN.glob("*.par")):
    raw = par.read_text()
    new = transform_par_text(raw)
    dst = PAR_OUT / par.name
    dst.write_text(new)
    transformed.append(dst)
    print(f"Compat-wrote {par.name}")

# --- Try building pulsars with PINT ---
from enterprise.pulsar import Pulsar
built = []
skipped = []

for par in transformed:
    tim = TIM_DIR / (par.stem + ".tim")
    if not tim.exists():
        skipped.append((par.name, "missing .tim")); continue
    try:
        psr = Pulsar(str(par), str(tim), timing_package="pint")
        built.append(psr)
        print(f"✔ {par.stem}: {len(psr.toas)} TOAs")
    except Exception as e:
        skipped.append((par.name, str(e)))
        print(f"✖ {par.stem} FAILED: {e}")

with open(OUT_PKL, "wb") as f:
    pickle.dump(built, f, protocol=pickle.HIGHEST_PROTOCOL)

print("\nSummary")
print("-------")
print(f"Saved {len(built)} pulsars (PINT) -> {OUT_PKL}")
if skipped:
    print("Remaining skips:", len(skipped))
    for name, reason in skipped:
        print("  ✖", name, "->", reason)
print(f"Transformed PARs are in: {PAR_OUT}")
# Out:
# Cleaned J0030+0451.par (removed 2 lines)
# Cleaned J0034-0534.par (removed 2 lines)
# Cleaned J0218+4232.par (removed 2 lines)
# Cleaned J0437-4715.par (removed 2 lines)
# Cleaned J0613-0200.par (removed 2 lines)
# Cleaned J0621+1002.par (removed 2 lines)
# Cleaned J0711-6830.par (removed 2 lines)
# Cleaned J0751+1807.par (removed 2 lines)
# Cleaned J0900-3144.par (removed 2 lines)
# Cleaned J1012+5307.par (removed 2 lines)
# Cleaned J1022+1001.par (removed 2 lines)
# Cleaned J1024-0719.par (removed 2 lines)
# Cleaned J1045-4509.par (removed 2 lines)
# Cleaned J1455-3330.par (removed 2 lines)
# Cleaned J1600-3053.par (removed 2 lines)
# Cleaned J1603-7202.par (removed 2 lines)
# Cleaned J1614-2230.par (removed 2 lines)
# Cleaned J1640+2224.par (removed 2 lines)
# Cleaned J1643-1224.par (removed 2 lines)
# Cleaned J1713+0747.par (removed 2 lines)
# Cleaned J1730-2304.par (removed 2 lines)
# Cleaned J1744-1134.par (removed 2 lines)
# Cleaned J1857+0943.par (removed 2 lines)
# Cleaned J1909-3744.par (removed 2 lines)
# Cleaned J1918-0642.par (removed 2 lines)
# Cleaned J1939+2134.par (removed 2 lines)
# Cleaned J1944+0907.par (removed 2 lines)
# Cleaned J2010-1323.par (removed 2 lines)
# Cleaned J2124-3358.par (removed 2 lines)
# Cleaned J2129-5721.par (removed 2 lines)
# Cleaned J2145-0750.par (removed 2 lines)
# Cleaned J2229+2643.par (removed 2 lines)
# Cleaned J2317+1439.par (removed 2 lines)
# ✖ J0030+0451 FAILED: PINT only supports 'UNITS TDB'
# ✖ J0034-0534 FAILED: Pulsar system/Binary model component T2 is not provided.
# ✖ J0218+4232 FAILED: Pulsar system/Binary model component T2 is not provided.
# ✖ J0437-4715 FAILED: Pulsar system/Binary model component T2 is not provided.
# /usr/local/anaconda/lib/python3.9/site-packages/pint/models/timing_model.py:371: UserWarning: PINT does not support 'DILATEFREQ Y'
#   warn("PINT does not support 'DILATEFREQ Y'")
# /usr/local/anaconda/lib/python3.9/site-packages/pint/models/timing_model.py:374: UserWarning: PINT only supports 'TIMEEPH FB90'
#   warn("PINT only supports 'TIMEEPH FB90'")
# ✖ J0613-0200 FAILED: Pulsar system/Binary model component T2 is not provided.
# ✖ J0621+1002 FAILED: Pulsar system/Binary model component T2 is not provided.
# ✖ J0711-6830 FAILED: PINT only supports 'UNITS TDB'
# ✖ J0751+1807 FAILED: Pulsar system/Binary model component T2 is not provided.
# ✖ J0900-3144 FAILED: Pulsar system/Binary model component T2 is not provided.
# ✖ J1012+5307 FAILED: Pulsar system/Binary model component T2 is not provided.
# ✖ J1022+1001 FAILED: Pulsar system/Binary model component DDH is not provided.
# ✖ J1024-0719 FAILED: PINT only supports 'UNITS TDB'
# ✖ J1045-4509 FAILED: Pulsar system/Binary model component T2 is not provided.
# ✖ J1455-3330 FAILED: Pulsar system/Binary model component T2 is not provided.
# ✖ J1600-3053 FAILED: Pulsar system/Binary model component DDH is not provided.
# ✖ J1603-7202 FAILED: Pulsar system/Binary model component T2 is not provided.
# ✖ J1614-2230 FAILED: PINT only supports 'UNITS TDB'
# ✖ J1640+2224 FAILED: Pulsar system/Binary model component T2 is not provided.
# ✖ J1643-1224 FAILED: Pulsar system/Binary model component T2 is not provided.
# ✖ J1713+0747 FAILED: Pulsar system/Binary model component T2 is not provided.
# ✖ J1730-2304 FAILED: PINT only supports 'UNITS TDB'
# ✖ J1744-1134 FAILED: PINT only supports 'UNITS TDB'
# ✖ J1857+0943 FAILED: Pulsar system/Binary model component T2 is not provided.
# ✖ J1909-3744 FAILED: Pulsar system/Binary model component T2 is not provided.
# ✖ J1918-0642 FAILED: Pulsar system/Binary model component DDH is not provided.
# ✖ J1939+2134 FAILED: PINT only supports 'UNITS TDB'
# ✖ J1944+0907 FAILED: PINT only supports 'UNITS TDB'
# ✖ J2010-1323 FAILED: PINT only supports 'UNITS TDB'
# ✖ J2124-3358 FAILED: PINT only supports 'UNITS TDB'
# ✖ J2129-5721 FAILED: Pulsar system/Binary model component T2 is not provided.
# ✖ J2145-0750 FAILED: Pulsar system/Binary model component T2 is not provided.
# ✖ J2229+2643 FAILED: Pulsar system/Binary model component T2 is not provided.
# ✖ J2317+1439 FAILED: Pulsar system/Binary model component T2 is not provided.
#
# Saved 0 pulsars (PINT) -> /scratch/na00078/projects/IPTA_MDC2/mdc2/group2/dataset_2/dataset2_all_pulsars_pint.pkl
# Skipped:
#   ✖ J0030+0451.par -> PINT only supports 'UNITS TDB'
#   ✖ J0034-0534.par -> Pulsar system/Binary model component T2 is not provided.
#   ✖ J0218+4232.par -> Pulsar system/Binary model component T2 is not provided.
#   ✖ J0437-4715.par -> Pulsar system/Binary model component T2 is not provided.
#   ✖ J0613-0200.par -> Pulsar system/Binary model component T2 is not provided.
#   ✖ J0621+1002.par -> Pulsar system/Binary model component T2 is not provided.
#   ✖ J0711-6830.par -> PINT only supports 'UNITS TDB'
#   ✖ J0751+1807.par -> Pulsar system/Binary model component T2 is not provided.
#   ✖ J0900-3144.par -> Pulsar system/Binary model component T2 is not provided.
#   ✖ J1012+5307.par -> Pulsar system/Binary model component T2 is not provided.
#   ✖ J1022+1001.par -> Pulsar system/Binary model component DDH is not provided.
#   ✖ J1024-0719.par -> PINT only supports 'UNITS TDB'
#   ✖ J1045-4509.par -> Pulsar system/Binary model component T2 is not provided.
#   ✖ J1455-3330.par -> Pulsar system/Binary model component T2 is not provided.
#   ✖ J1600-3053.par -> Pulsar system/Binary model component DDH is not provided.
#   ✖ J1603-7202.par -> Pulsar system/Binary model component T2 is not provided.
#   ✖ J1614-2230.par -> PINT only supports 'UNITS TDB'
#   ✖ J1640+2224.par -> Pulsar system/Binary model component T2 is not provided.
#   ✖ J1643-1224.par -> Pulsar system/Binary model component T2 is not provided.
#   ✖ J1713+0747.par -> Pulsar system/Binary model component T2 is not provided.
#   ✖ J1730-2304.par -> PINT only supports 'UNITS TDB'
#   ✖ J1744-1134.par -> PINT only supports 'UNITS TDB'
#   ✖ J1857+0943.par -> Pulsar system/Binary model component T2 is not provided.
#   ✖ J1909-3744.par -> Pulsar system/Binary model component T2 is not provided.
#   ✖ J1918-0642.par -> Pulsar system/Binary model component DDH is not provided.
#   ✖ J1939+2134.par -> PINT only supports 'UNITS TDB'
#   ✖ J1944+0907.par -> PINT only supports 'UNITS TDB'
#   ✖ J2010-1323.par -> PINT only supports 'UNITS TDB'
#   ✖ J2124-3358.par -> PINT only supports 'UNITS TDB'
#   ✖ J2129-5721.par -> Pulsar system/Binary model component T2 is not provided.
#   ✖ J2145-0750.par -> Pulsar system/Binary model component T2 is not provided.
#   ✖ J2229+2643.par -> Pulsar system/Binary model component T2 is not provided.
#   ✖ J2317+1439.par -> Pulsar system/Binary model component T2 is not provided.
#
# Cleaned PARs are in: /scratch/na00078/projects/IPTA_MDC2/mdc2/group2/dataset_2/par_pint_clean
