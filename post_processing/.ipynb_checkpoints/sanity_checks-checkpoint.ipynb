# %%
import h5py
with h5py.File("/scratch/na00078/projects/IPTA_MDC2/h5_files/G2D1_broad_UL_loki_29_Apr_2026.h5", "r") as f:
    par_names = [x.decode("UTF-8") for x in f["par_names"][...]]
print([p for p in par_names if "gwb" in p.lower()])
# Out:
# ['gwb_gamma', 'gwb_log10_A']

# %%
import h5py
with h5py.File("/scratch/na00078/projects/IPTA_MDC2/h5_files/G2D1_broad_UL_1e9_fixed_gamma.h5", "r") as f:
    par_names = [x.decode("UTF-8") for x in f["par_names"][...]]
print([p for p in par_names if "gwb" in p.lower()])
# Out:
# []
